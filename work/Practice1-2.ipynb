# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

# %%
# 프롬프트 템플릿 정의
prompt = ChatPromptTemplate.from_template("주제 {topic}에 대해 짧은 설명을 해주세요.")

# %%
model = ChatOpenAI(
    model = "gemma-4-e2b-it",
    base_url = "http://host.docker.internal:12345/v1",
    api_key="lm-studio",
    temperature=0.7
)

output_parser = StrOutputParser()

# %%
chain = (
    { "topic": RunnablePassthrough() }
    | prompt
    | model
    | output_parser
)

chain.invoke("SCA")
# Out:
# '## SCA (Software Composition Analysis) 란 무엇인가요?\n\n**SCA(Software Composition Analysis)**는 소프트웨어 개발 과정에서 **사용되는 오픈 소스 라이브러리 및 상용 컴포넌트의 구성 요소(종속성, Dependencies)를 식별하고 분석하는 자동화된 프로세스**입니다.\n\n쉽게 말해, **"우리 소프트웨어가 어떤 외부 라이브러리를 사용하고 있는지 확인하고, 그 라이브러리에 잠재적인 보안 취약점이나 라이선스 문제가 없는지 검사하는 도구"**라고 생각할 수 있습니다.\n\n---\n\n### 핵심 기능 및 중요성\n\n1. **취약점(Vulnerability) 탐지:**\n   * 사용 중인 오픈 소스 라이브러리 데이터베이스와 비교하여, 알려진 보안 취약점(CVE 등)이 포함된 라이브러리가 있는지 자동으로 찾아냅니다. (가장 중요한 기능)\n\n2. **라이선스 준수 확인:**\n   * 사용된 각 컴포넌트의 라이선스(예: MIT, GPL 등)를 식별하여, 회사의 정책이나 법적 요구사항에 위배되는 라이선스가 사용되지 않도록 확인합니다.\n\n3. **투명성 및 거버넌스 확보:**\n   * 프로젝트가 어떤 외부 코드를 기반으로 하는지 명확하게 파악하여 소프트웨어 공급망(Supply Chain)의 투명성을 높입니다.\n\n### 왜 SCA가 중요한가요?\n\n현대의 소프트웨어는 대부분 오픈 소스 라이브러리에 크게 의존하고 있습니다. 만약 이 라이브러리 중 하나에 심각한 보안 취약점이 있다면, 우리 제품에도 그 취약점이 그대로 포함되어 **데이터 유출이나 시스템 마비**와 같은 심각한 보안 사고로 이어질 수 있습니다.\n\n**결론적으로, SCA는 개발 초기 단계부터 최종 배포 단계까지 소프트웨어의 \'구성 요소\'에 대한 위험을 사전에 파악하고 관리하여, 더 안전하고 법적으로 문제가 없는 소프트웨어를 만들도록 돕는 필수적인 보안 및 품질 관리 도구입니다.**'
